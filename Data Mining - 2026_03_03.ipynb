# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/datamining_pratical1.csv")
df.head()
# Out:
#    Student_ID       Name  Age Gender Department   GPA  Attendance  Projects  \
# 0           1  Student_1   24   Male         SE  3.70        76.0         0
# 1           2  Student_2   24   Male         DS  3.70        76.0         0
# 2           3  Student_3   22   Male         SE  2.90        50.0         3
# 3           4  Student_4   24   Male         DS  2.19        82.0         2
# 4           5  Student_5   20   Male         IT  3.14       100.0         5
#
#   Internship Graduated
# 0         No        No
# 1         No        No
# 2        Yes        No
# 3        Yes        No
# 4         No       Yes

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Female    31
# Male      15
# Fe         2
# Ma         2
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (50, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  50 non-null     int64
#  1   Name        50 non-null     object
#  2   Age         50 non-null     int64
#  3   Gender      50 non-null     object
#  4   Department  50 non-null     object
#  5   GPA         50 non-null     float64
#  6   Attendance  47 non-null     float64
#  7   Projects    50 non-null     int64
#  8   Internship  50 non-null     object
#  9   Graduated   50 non-null     object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 4.0+ KB

# %%
df.describe()
# Out:
#        Student_ID       Age        GPA  Attendance  Projects
# count    50.00000  50.00000  50.000000   47.000000   50.0000
# mean     25.50000  21.34000   3.001600   74.723404    1.9600
# std      14.57738   1.89101   0.548495   16.390217    1.5513
# min       1.00000  18.00000   2.000000   50.000000    0.0000
# 25%      13.25000  20.00000   2.542500   60.000000    0.2500
# 50%      25.50000  21.00000   3.120000   76.000000    2.0000
# 75%      37.75000  23.00000   3.397500   87.500000    3.0000
# max      50.00000  24.00000   3.940000  100.000000    5.0000

# %%
df.isnull().sum()
# Out:
# Student_ID    0
# Name          0
# Age           0
# Gender        0
# Department    0
# GPA           0
# Attendance    3
# Projects      0
# Internship    0
# Graduated     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Attendance"] = df["Attendance"].fillna(df["Attendance"].mean())
df.isnull().sum()
# Out:
# Student_ID    0
# Name          0
# Age           0
# Gender        0
# Department    0
# GPA           0
# Attendance    0
# Projects      0
# Internship    0
# Graduated     0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.dtypes
# Out:
# Student_ID      int64
# Name           object
# Age             int64
# Gender         object
# Department     object
# GPA           float64
# Attendance    float64
# Projects        int64
# Internship     object
# Graduated      object
# dtype: object

# %%
df["Gender"] = df["Gender"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_399/1693540283.py in <cell line: 0>()
# ----> 1 df["Gender"] = df["Gender"].astype(int)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# ...

# %%
df["Gender"] = df["Gender"].apply(lambda x: 1 if x == "Male" else 0)
df["Gender"].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Gender, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encorder = LabelEncoder()
df["Gender"] = encorder.fit_transform(df["Gender"])
df["Gender"].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Gender, dtype: int64

# %%
dic = {
    "Male" : 1,
    "Ma": 1,
    "Fe":0,
    "Female" : 0
}
df["Gender"] = df["Gender"].map(dic)

# %%
df["Gender"].value_counts()
# Out:
# Gender
# 0    33
# 1    17
# Name: count, dtype: int64

# %%
df
# Out:
#     Student_ID        Name  Age  Gender Department   GPA  Attendance  \
# 0            1   Student_1   24       1         SE  3.70        76.0
# 1            2   Student_2   24       1         DS  3.70        76.0
# 2            3   Student_3   22       1         SE  2.90        50.0
# 3            4   Student_4   24       1         DS  2.19        82.0
# 4            5   Student_5   20       1         IT  3.14       100.0
# 5            6   Student_6   22       1         SE  3.34        91.0
# 6            7   Student_7   22       0         DS  3.33        93.0
# 7            8   Student_8   24       0         CS  3.18        73.0
# 8            9   Student_9   19       1         IT  2.55        64.0
# 9           10  Student_10   20       0         DS  3.12        81.0
# 10          11  Student_11   24       0         CS  2.77        81.0
# 11          12  Student_12   20       0         DS  3.94        73.0
# 12          13  Student_13   20       0         CS  3.70        90.0
# ...

# %%
df = df.rename(columns={"Projects": "Project"})

# %%
df.columns
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Gender', 'Department', 'GPA',
#        'Attendance', 'Project', 'Internship', 'Graduated'],
#       dtype='object')

# %%
df.head()
# Out:
#    Student_ID       Name  Age  Gender Department   GPA  Attendance  Project  \
# 0           1  Student_1   24       1         SE  3.70        76.0        0
# 1           2  Student_2   24       1         DS  3.70        76.0        0
# 2           3  Student_3   22       1         SE  2.90        50.0        3
# 3           4  Student_4   24       1         DS  2.19        82.0        2
# 4           5  Student_5   20       1         IT  3.14       100.0        5
#
#   Internship Graduated
# 0         No        No
# 1         No        No
# 2        Yes        No
# 3        Yes        No
# 4         No       Yes

# %%
invalid_attendance = df[(df["Attendance"] > 100) | (df["Attendance"] < 0)]
invalid_attendance.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.loc[50] = {'Student_ID': len(df), 'Name': f"Student_{len(df)}", 'Age': df.Age.median(),"Gender":1,"Department":"SE","GPA":3.6,"Attendance":9000,"Project":4,"Internship":"Yes","Graduated":"No"}

# %%
df.iloc[len(df) - 1]
# Out:
# Student_ID            51
# Name          Student_51
# Age                 21.0
# Gender                 1
# Department            SE
# GPA                  3.6
# Attendance        9000.0
# Project                4
# Internship           Yes
# Graduated             No
# Name: 50, dtype: object

# %%
df["Attendance"].mean()
# Out:
# np.float64(260.6666666666667)

# %%
invalid_attendance = df[(df["Attendance"] > 100) | (df["Attendance"] < 0)]
invalid_attendance.value_counts()
# Out:
# Student_ID  Name        Age   Gender  Department  GPA  Attendance  Project  Internship  Graduated
# 51          Student_51  21.0  1       SE          3.6  9000.0      4        Yes         No           1
# Name: count, dtype: int64

# %%
df.to_csv("Cleaned_School_attendance.csv",index=False)

# %%
from google.colab import files
files.download("Cleaned_School_attendance.csv")
